# %% [markdown]
# <a href="https://colab.research.google.com/github/Lakshmi-krishna-vr/ML-foundations-and-advanced-techniques/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pandas library -2d tabular

# %%
import pandas as pd

# %% [markdown]
# ## creating a pandas dataframe

# %%
from sklearn.datasets import fetch_california_housing
housing = fetch_california_housing()

# %%
type(housing)
# Out:
# sklearn.utils._bunch.Bunch

# %%
print(housing)
# Out:
# {'data': array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#           37.88      , -122.23      ],
#        [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#           37.86      , -122.22      ],
#        [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#           37.85      , -122.24      ],
#        ...,
#        [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#           39.43      , -121.22      ],
#        [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#           39.43      , -121.32      ],
#        [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
# ...

# %%
#pandas dataset
housing_df= pd.DataFrame(housing.data, columns= housing.feature_names)

# %%
housing_df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
housing_df.shape
# Out:
# (20640, 8)

# %%
book1_df=pd.read_csv('/content/Book1.csv')

# %%
type(housing_df)
# Out:
# pandas.core.frame.DataFrame

# %%
book1_df.head()
# Out:
#   Series_reference,Period,Data_value,Suppressed,STATUS,UNITS,Magnitude,Subject,Group,Series_title_1,Series_title_2,Series_title_3,Series_title_4,Series_title_5
# 0  BDCQ.SF1AA2CA,2016.06,1116.386,,F,Dollars,6,Bu...
# 1  BDCQ.SF1AA2CA,2016.09,1070.874,,F,Dollars,6,Bu...
# 2  BDCQ.SF1AA2CA,2016.12,1054.408,,F,Dollars,6,Bu...
# 3  BDCQ.SF1AA2CA,2017.03,1010.665,,F,Dollars,6,Bu...
# 4  BDCQ.SF1AA2CA,2017.06,1233.7,,F,Dollars,6,Busi...

# %%
book1_df.shape
# Out:
# (8355, 1)

# %% [markdown]
# pd.read_ excel("file path")

# %%
housing_df.to_csv('housing.csv')

# %%
housing_df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
housing_df.value_counts('Latitude')
# Out:
# Latitude
# 34.06    244
# 34.05    236
# 34.08    234
# 34.07    231
# 34.04    221
#         ...
# 41.23      1
# 41.28      1
# 41.30      1
# 41.88      1
# 41.92      1
# Name: count, Length: 862, dtype: int64

# %%
housing_df.groupby('Latitude').mean()
# Out:
#             MedInc   HouseAge  AveRooms  AveBedrms   Population  AveOccup  \
# Latitude
# 32.54     1.266700   7.000000  3.326241   1.053191  1187.000000  4.209220
# 32.55     2.343833   9.333333  4.242959   1.044896  3530.666667  3.932016
# 32.56     2.764300  15.500000  4.341508   1.043155  2238.700000  5.150666
# 32.57     3.368961  19.277778  5.074204   1.012189  1781.500000  3.895275
# 32.58     3.385735  22.730769  4.866881   1.026222  1367.192308  3.344389
# ...            ...        ...       ...        ...          ...       ...
# 41.84     3.031300  17.000000  5.870614   1.164474  1244.000000  2.728070
# 41.86     2.232067  24.000000  5.891849   1.209441  1532.333333  2.677139
# 41.88     3.130000  18.000000  5.829457   1.383721   660.000000  2.558140
# 41.92     2.133600  19.000000  5.893993   1.144876   841.000000  2.971731
# 41.95     2.049600  19.500000  5.701675   1.260179  1005.000000  2.499742
#
#            Longitude
# Latitude
# 32.54    -117.040000
# ...

# %%
housing_df.count()
# Out:
# MedInc        20640
# HouseAge      20640
# AveRooms      20640
# AveBedrms     20640
# Population    20640
# AveOccup      20640
# Latitude      20640
# Longitude     20640
# dtype: int64

# %%
housing_df.mean()
# Out:
# MedInc           3.870671
# HouseAge        28.639486
# AveRooms         5.429000
# AveBedrms        1.096675
# Population    1425.476744
# AveOccup         3.070655
# Latitude        35.631861
# Longitude     -119.569704
# dtype: float64

# %%
housing_df.std()
# Out:
# MedInc           1.899822
# HouseAge        12.585558
# AveRooms         2.474173
# AveBedrms        0.473911
# Population    1132.462122
# AveOccup        10.386050
# Latitude         2.135952
# Longitude        2.003532
# dtype: float64

# %%
housing_df.min()
housing_df.max()
# Out:
# MedInc           15.000100
# HouseAge         52.000000
# AveRooms        141.909091
# AveBedrms        34.066667
# Population    35682.000000
# AveOccup       1243.333333
# Latitude         41.950000
# Longitude      -114.310000
# dtype: float64

# %%
housing_df.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude
# count  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704
# std       10.386050      2.135952      2.003532
# min        0.692308     32.540000   -124.350000
# ...

# %% [markdown]
# ## Manipulating data frame

# %%
#adding value
housing_df['Latitude']= housing.target

# %%
housing_df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     4.526
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     3.585
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     3.521
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     3.413
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     3.422
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
housing_df.drop(columns='HouseAge',axis=1)
# Out:
#        MedInc  AveRooms  AveBedrms  Population  AveOccup  Latitude  Longitude
# 0      8.3252  6.984127   1.023810       322.0  2.555556     4.526    -122.23
# 1      8.3014  6.238137   0.971880      2401.0  2.109842     3.585    -122.22
# 2      7.2574  8.288136   1.073446       496.0  2.802260     3.521    -122.24
# 3      5.6431  5.817352   1.073059       558.0  2.547945     3.413    -122.25
# 4      3.8462  6.281853   1.081081       565.0  2.181467     3.422    -122.25
# ...       ...       ...        ...         ...       ...       ...        ...
# 20635  1.5603  5.045455   1.133333       845.0  2.560606     0.781    -121.09
# 20636  2.5568  6.114035   1.315789       356.0  3.122807     0.771    -121.21
# 20637  1.7000  5.205543   1.120092      1007.0  2.325635     0.923    -121.22
# 20638  1.8672  5.329513   1.171920       741.0  2.123209     0.847    -121.32
# 20639  2.3886  5.254717   1.162264      1387.0  2.616981     0.894    -121.24
#
# [20640 rows x 7 columns]

# %%
housing_df.iloc[2]
# Out:
# MedInc          7.257400
# HouseAge       52.000000
# AveRooms        8.288136
# AveBedrms       1.073446
# Population    496.000000
# AveOccup        2.802260
# Latitude        3.521000
# Longitude    -122.240000
# Name: 2, dtype: float64

# %%
print(housing_df.iloc[:1])
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127    1.02381       322.0  2.555556     4.526
#
#    Longitude
# 0    -122.23

# %%
housing_df.corr()
# Out:
#               MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc      1.000000 -0.119034  0.326895  -0.062040    0.004834  0.018766
# HouseAge   -0.119034  1.000000 -0.153277  -0.077747   -0.296244  0.013191
# AveRooms    0.326895 -0.153277  1.000000   0.847621   -0.072213 -0.004852
# AveBedrms  -0.062040 -0.077747  0.847621   1.000000   -0.066197 -0.006181
# Population  0.004834 -0.296244 -0.072213  -0.066197    1.000000  0.069863
# AveOccup    0.018766  0.013191 -0.004852  -0.006181    0.069863  1.000000
# Latitude    0.688075  0.105623  0.151948  -0.046701   -0.024650 -0.023737
# Longitude  -0.015176 -0.108197 -0.027540   0.013344    0.099773  0.002476
#
#             Latitude  Longitude
# MedInc      0.688075  -0.015176
# HouseAge    0.105623  -0.108197
# AveRooms    0.151948  -0.027540
# AveBedrms  -0.046701   0.013344
# Population -0.024650   0.099773
# AveOccup   -0.023737   0.002476
# Latitude    1.000000  -0.045967
# Longitude  -0.045967   1.000000
